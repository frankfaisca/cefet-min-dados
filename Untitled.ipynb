# %%
library("dbscan")
library("fpc")
library("factoextra")
# Out:
# Attaching package: ‘dbscan’
#
#
# The following object is masked from ‘package:stats’:
#
#     as.dendrogram
#
#
#
# Attaching package: ‘fpc’
#
#
# The following object is masked from ‘package:dbscan’:
#
#     dbscan
#
#
# Loading required package: ggplot2
#
# Welcome! Want to learn more? See two factoextra-related books at https://goo.gl/ve3WBa

# %%
# Load the data 
# Make sure that the package factoextra is installed
data("multishapes", package = "factoextra")
df <- multishapes[, 1:2]

df

library("fpc")
# Compute DBSCAN using fpc package
set.seed(123)
db <- fpc::dbscan(df, eps = 0.15, MinPts = 5)
# Plot DBSCAN results
plot(db, df, main = "DBSCAN", frame = FALSE)
# Out:
#      x            y
# 1    -0.803739265 -0.85305261
# 2     0.852850728  0.36761844
# 3     0.927179506 -0.27490244
# 4    -0.752626057 -0.51156517
# 5     0.706846224  0.81067920
# 6     1.034698522  0.39465502
# 7    -0.475845198  0.98976081
# 8    -0.460301567 -0.85899779
# 9    -0.680301545 -0.66149481
# 10   -1.031969300 -0.02199354
# 11   -0.242498372 -1.05033276
# 12   -0.892258364 -0.33916923
# 13   -0.802034404 -0.77416777
# 14   -0.047195569 -1.01613799
# 15    1.194704267 -0.26900246
# 16   -0.221487390 -0.91913190
# 17   -0.410475320  0.96447900
# 18   -0.838935270 -0.40797904
# 19   -0.889147511  0.61401611
# 20    0.905564127  0.18456840
# 21   -0.005794852 -0.88443071
# 22   -0.703810395  0.54749249
# 23   -1.070815706 -0.15898275
# 24    1.007237619  0.38517535
# 25   -0.584861589  0.70011771
# 26   -0.881140153 -0.01188876
# 27    0.326995043  0.99890856
# 28   -1.047621138  0.11854357
# 29   -0.119960489 -1.03541073
# 30   -0.785532936  0.71341847
# ⋮    ⋮            ⋮
# 1071 0.9693378    -2.559469
# 1072 1.1303418    -2.688269
# 1073 0.8941340    -2.281969
# 1074 1.0301720    -2.462122
# 1075 1.0089973    -2.606931
# 1076 0.8636608    -2.537514
# 1077 1.0282524    -2.579480
# 1078 1.1580699    -2.468488
# 1079 1.0940040    -2.486606
# 1080 1.1131430    -2.624055
# 1081 0.9786304    -2.474352
# 1082 1.0957839    -2.567407
# 1083 0.7629190    -2.436677
# 1084 0.8746741    -2.439764
# 1085 0.9825152    -2.503403
# 1086 1.0108512    -2.578971
# 1087 1.0516920    -2.547044
# 1088 1.0721634    -2.601282
# 1089 0.9540056    -2.416645
# 1090 0.9518388    -2.364598
# 1091 0.9650725    -2.494993
# 1092 0.9438234    -2.466312
# 1093 0.9875297    -2.520900
# 1094 1.0877552    -2.478154
# 1095 1.0463347    -2.312652
# 1096 0.9560635    -2.473828
# 1097 0.9307583    -2.366531
# 1098 0.9895547    -2.475225
# 1099 0.9792000    -2.637578
# 1100 1.1219308    -2.619054
# Plot with title “DBSCAN”

# %%
fviz_cluster(db, df, stand = FALSE, frame = FALSE, geom = "point")
# Out:
# Warning message:
# “argument frame is deprecated; please use ellipse instead.”
# plot without title

# %%
# Compute DBSCAN using fpc package
set.seed(123)
db <- fpc::dbscan(df, eps = 0.15, MinPts = 5)
# Plot DBSCAN results
plot(db, df, main = "DBSCAN", frame = FALSE)
# Out:
# Plot with title “DBSCAN”
